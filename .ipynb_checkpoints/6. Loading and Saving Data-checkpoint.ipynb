# %%
import pandas as pd
import networkx as nx
import os

# %% [markdown]
# # Tables to Networks
#
# If you have relational data currently stored in a tabular format, then you've got data ready to go.
#
# Networks can be represented in a tabular form in two ways: As an adjacency list with edge attributes stored as columnar values, and as a node list with node attributes stored as columnar values.
#
# Here, we will get you set up and ready for the free-hacking session. To do this, we will learn how to load data from a CSV file into a Pandas DataFrame, and then iterate over the data to create the NetworkX network, which you can then use to perform the analyses that answer the exercise questions below. Along the way, we will also answer one network question, "What set of stations are important?"

# %% [markdown]
# # Loading Node Lists and Adjacency Lists
#
# Let's use the Divvy bike sharing data set as a starting point. The Divvy data set is comprised of the following data:
#
# - Stations and metadata (like a node list with attributes saved)
# - Trips and metadata (like an edge list with attributes saved)
#
# The `README.txt` file in the Divvy directory should help orient you around the data.

# %%
os.chdir('datasets/divvy_2013')

# %%
stations = pd.read_csv('Divvy_Stations_2013.csv', parse_dates=['online date'], index_col='id')
stations
# Out:
#                               name   latitude  longitude  dpcapacity  \
# id
# 5           State St & Harrison St  41.873958 -87.627739          19
# 13      Wilton Ave & Diversey Pkwy  41.932500 -87.652681          19
# 14             Morgan St & 18th St  41.858086 -87.651073          15
# 15            Racine Ave & 18th St  41.858181 -87.656487          15
# 16             Wood St & North Ave  41.910329 -87.672516          15
# 17           Wood St & Division St  41.903320 -87.672730          15
# 19           Loomis St & Taylor St  41.869417 -87.660996          15
# 20    Sheffield Ave & Kingsbury St  41.909592 -87.653497          15
# 21      Aberdeen St & Jackson Blvd  41.877726 -87.654787          15
# 22              May St & Taylor St  41.869482 -87.655486          15
# 23             Orleans St & Elm St  41.902924 -87.637715          15
# 24        Fairbanks Ct & Grand Ave  41.891860 -87.620620          15
# 25       Michigan Ave & Pearson St  41.897660 -87.623510          23
# 26        McClurg Ct & Illinois St  41.891020 -87.617300          23
# 27         Larrabee St & North Ave  41.910210 -87.643500          19
# 28      Larrabee St & Menomonee St  41.914680 -87.643320          15
# 29        Noble St & Milwaukee Ave  41.900680 -87.662600          15
# 30      Ashland Ave & Augusta Blvd  41.899643 -87.667700          15
# 31       Franklin St & Chicago Ave  41.896802 -87.635638          23
# 32      Racine Ave & Congress Pkwy  41.874640 -87.657030          19
# 33         State St & Van Buren St  41.877181 -87.627844          27
# 34       Cannon Dr & Fullerton Ave  41.926756 -87.634429          15
# 35       Streeter Dr & Illinois St  41.891071 -87.612200          35
# 36      Franklin St & Jackson Blvd  41.877708 -87.635321          27
# 37          Dearborn St & Adams St  41.879356 -87.629791          19
# 42          Wabash Ave & Cermak Rd  41.853239 -87.625337          15
# 43    Michigan Ave & Washington St  41.883893 -87.624649          43
# 44          State St & Randolph St  41.884730 -87.627734          27
# 45    Michigan Ave & Congress Pkwy  41.876066 -87.624433          15
# 46            Wells St & Walton St  41.899930 -87.634430          19
# ..                             ...        ...        ...         ...
# 322          Kimbark Ave & 53rd St  41.799568 -87.594747          15
# 323     Sheridan Rd & Lawrence Ave  41.969517 -87.654691          15
# 324   Stockton Dr & Wrightwood Ave  41.931320 -87.638742          15
# 325        Clark St & Winnemac Ave  41.973385 -87.668365          15
# 326          Clark St & Leland Ave  41.967096 -87.667429          11
# 327    Sheffield Ave & Webster Ave  41.921687 -87.653714          19
# 328            Ellis Ave & 58th St  41.788746 -87.601334          15
# 329  Lake Shore Dr & Diversey Pkwy  41.932684 -87.636250          15
# 330       Lincoln Ave & Addison St  41.946176 -87.673308          19
# 331      Halsted St & Blackhawk St  41.908540 -87.648568          19
# 332     Halsted St & Diversey Pkwy  41.933341 -87.648747          15
# 333     Ashland Ave & Blackhawk St  41.907066 -87.667252          15
# 334    Lake Shore Dr & Belmont Ave  41.940775 -87.639192          19
# 335          Calumet Ave & 35th St  41.831379 -87.618034          15
# 336    Cottage Grove Ave & 47th St  41.809855 -87.606755          15
# 337         Clark St & Chicago Ave  41.896544 -87.630931          19
# 338          Calumet Ave & 18th St  41.857611 -87.619407          15
# 339          Emerald Ave & 31st St  41.838198 -87.645143          11
# 340      Clark St & Wrightwood Ave  41.929546 -87.643118          15
# 341              Adler Planetarium  41.866095 -87.607267          19
# 342          Wolcott Ave & Polk St  41.871262 -87.673688          15
# 343    Racine Ave & Wrightwood Ave  41.928887 -87.658971          15
# 344     Wolcott Ave & Lawrence Ave  41.968641 -87.676335          15
# 345        Lake Park Ave & 56th St  41.793242 -87.587782          15
# 346       Ada St & Washington Blvd  41.882830 -87.661206          15
# 347         Ashland Ave & Grace St  41.950687 -87.668700          15
# 348       California Ave & 21st St  41.854016 -87.695445          15
# 349    Halsted St & Wrightwood Ave  41.929143 -87.649077          15
# 350      Ashland Ave & Chicago Ave  41.895966 -87.667747          15
# 351    Cottage Grove Ave & 51st St  41.803038 -87.606615          15
#
#      landmark online date
# id
# 5          30  2013-06-28
# 13         66  2013-06-28
# 14        163  2013-06-28
# 15        164  2013-06-28
# 16        223  2013-08-12
# 17        246  2013-06-28
# 19        139  2013-06-28
# 20        154  2013-06-28
# 21        157  2013-06-28
# 22        160  2013-06-28
# 23        172  2013-06-28
# 24        262  2013-06-28
# 25         34  2013-06-28
# 26         51  2013-06-28
# 27        174  2013-06-28
# 28        282  2013-06-28
# 29        290  2013-06-28
# 30        248  2013-06-28
# 31         17  2013-06-28
# 32         76  2013-06-28
# 33          3  2013-06-28
# 34        124  2013-06-28
# 35         22  2013-08-05
# 36         19  2013-06-28
# 37         20  2013-06-28
# 42        170  2013-06-28
# 43          1  2013-06-28
# 44          2  2013-06-28
# 45         40  2013-06-28
# 46         46  2013-06-28
# ..        ...         ...
# 322       397  2013-09-21
# 323       384  2013-09-23
# 324       276  2013-10-03
# 325       392  2013-09-23
# 326       239  2013-09-27
# 327       188  2013-09-25
# 328       365  2013-09-25
# 329       347  2013-09-25
# 330        77  2013-09-26
# 331       176  2013-09-28
# 332       208  2013-09-28
# 333       224  2013-09-27
# 334       233  2013-09-27
# 335       345  2013-10-17
# 336       422  2013-10-17
# 337       303  2013-09-27
# 338       102  2013-09-28
# 339       404  2013-09-28
# 340       209  2013-10-24
# 341       431  2013-10-09
# 342       284  2013-10-12
# 343       297  2013-10-24
# 344        26  2013-10-09
# 345       119  2013-10-09
# 346       353  2013-10-10
# 347       319  2013-10-12
# 348        96  2013-10-14
# 349       210  2013-10-28
# 350       247  2013-10-22
# 351       440  2013-10-17
#
# [300 rows x 6 columns]

# %%
trips = pd.read_csv('Divvy_Trips_2013.csv', parse_dates=['starttime', 'stoptime'], index_col=['trip_id'])
trips
# Out:
#                   starttime            stoptime  bikeid  tripduration  \
# trip_id
# 1108868               31       Franklin St & Chicago Ave            110
# 1108894               49         Dearborn St & Monroe St            175
# 1108945              181        LaSalle St & Illinois St             73
# 1108955               49         Dearborn St & Monroe St             59
# 1108974               26        McClurg Ct & Illinois St             56
# 1109063              110              State St & Erie St            176
# 1109084               50        Clark St & Congress Pkwy            170
# 1109198              214           Damen Ave & Grand Ave            285
# 1109223              234         Clark St & Montrose Ave            318
# 1109256               60           Dayton St & North Ave             20
# 1109257               20    Sheffield Ave & Kingsbury St             93
# 1109276              227    Southport Ave & Waveland Ave            228
# 1109283              284     Michigan Ave & Jackson Blvd             43
# 1109309              130         Damen Ave & Division St             69
# 1109338              216    California Ave & Division St             69
#
#                           to_station_name    usertype  gender  birthday
# trip_id
# 4118           Larrabee St & Menomonee St    Customer     NaN       NaN
# 4275           Racine Ave & Congress Pkwy    Customer     NaN       NaN
# 4291                Loomis St & Taylor St    Customer     NaN       NaN
# 4316                Loomis St & Taylor St    Customer     NaN       NaN
# 4342     Halsted St & James M Rochford St    Customer     NaN       NaN
# 4480                 Wells St & Walton St    Customer     NaN       NaN
# 4490            Lake Shore Dr & Monroe St    Customer     NaN       NaN
# 4592              Canal St & Jackson Blvd    Customer     NaN       NaN
# 4602               Dearborn St & Adams St    Customer     NaN       NaN
# 4607            Clark St & Wrightwood Ave    Customer     NaN       NaN
# 4617               State St & Randolph St    Customer     NaN       NaN
# 4619             Fairbanks Ct & Grand Ave    Customer     NaN       NaN
# 4644                 Wells St & Walton St    Customer     NaN       NaN
# 4646               Michigan Ave & Lake St    Customer     NaN       NaN
# 4647               Michigan Ave & Lake St    Customer     NaN       NaN
# 4666               Michigan Ave & Lake St    Customer     NaN       NaN
# 4793             Noble St & Milwaukee Ave    Customer     NaN       NaN
# 4863                Wood St & Division St    Customer     NaN       NaN
# 4865                Michigan Ave & Oak St    Customer     NaN       NaN
# 4866                Michigan Ave & Oak St    Customer     NaN       NaN
# 4867                Wood St & Division St    Customer     NaN       NaN
# 4869                Wood St & Division St    Customer     NaN       NaN
# 4874                  Wood St & North Ave    Customer     NaN       NaN
# 4875                  Wood St & North Ave    Customer     NaN       NaN
# 4883                Michigan Ave & Oak St    Customer     NaN       NaN
# 4896                Michigan Ave & Oak St    Customer     NaN       NaN
# 4897                Michigan Ave & Oak St    Customer     NaN       NaN
# 4902              Wood St & Milwaukee Ave    Customer     NaN       NaN
# 4943             California Ave & 21st St    Customer     NaN       NaN
# 4946            Cannon Dr & Fullerton Ave    Customer     NaN       NaN
# ...                                   ...         ...     ...       ...
# 1108595              Clinton St & Lake St  Subscriber  Female      1981
# 1108597         Halsted St & Waveland Ave  Subscriber  Female      1988
# 1108600       Dearborn Pkwy & Delaware Pl  Subscriber  Female      1981
# 1108621               Canal St & Adams St  Subscriber  Female      1987
# 1108631           Dearborn St & Monroe St  Subscriber  Female      1957
# 1108658    California Ave & Milwaukee Ave  Subscriber  Female      1972
# 1108659               Wood St & North Ave  Subscriber  Female      1975
# 1108740             St Clair St & Erie St  Subscriber  Female      1988
# 1108749    Southport Ave & Wellington Ave  Subscriber  Female      1986
# 1108754      Ravenswood Ave & Berteau Ave  Subscriber  Female      1964
# 1108756         Wabash Ave & Roosevelt Rd  Subscriber  Female      1975
# 1108773    Sheffield Ave & Wellington Ave  Subscriber  Female      1986
# 1108836          LaSalle St & Illinois St  Subscriber  Female      1988
# 1108846         Franklin St & Chicago Ave  Subscriber  Female      1983
# 1108852                Wells St & Polk St  Subscriber  Female      1957
# 1108868                State St & Erie St  Subscriber  Female      1983
# 1108894                Wells St & Polk St  Subscriber  Female      1979
# 1108945          Jefferson St & Monroe St  Subscriber  Female      1988
# 1108955         Wabash Ave & Roosevelt Rd  Subscriber  Female      1980
# 1108974         Desplaines St & Kinzie St  Subscriber  Female      1965
# 1109063                 Clark St & Elm St  Subscriber  Female      1983
# 1109084              Clinton St & 18th St  Subscriber  Female      1973
# 1109198               Wood St & Grand Ave  Subscriber  Female      1979
# 1109223    Southport Ave & Irving Park Rd  Subscriber  Female      1981
# 1109256      Sheffield Ave & Kingsbury St  Subscriber  Female      1983
# 1109257         Sheffield Ave & Willow St  Subscriber  Female      1983
# 1109276           Damen Ave & Melrose Ave  Subscriber  Female      1978
# 1109283      Michigan Ave & Washington St  Subscriber  Female      1976
# 1109309            Damen Ave & Pierce Ave  Subscriber  Female      1976
# 1109338            Damen Ave & Pierce Ave  Subscriber  Female      1978
#
# [759788 rows x 11 columns]

# %% [markdown]
# At this point, we have our `stations` and `trips` data loaded into memory. How we construct the graph depends on the kind of questions we want to answer, so the definition of the "unit of consideration" is extremely important. In this case, the bike station is a reasonable "unit of consideration", so we will use the bike stations as the nodes.
#
# To start, let's initialize an directed graph `G`.

# %%
G = nx.DiGraph()

# %% [markdown]
# Then, let's iterate over the `stations` DataFrame, and add in the node attributes.

# %%
for r, d in stations.iterrows(): # call the pandas DataFrame row-by-row iterator
    G.add_node(r, attr_dict=d.to_dict())

# %% [markdown]
# In order to answer the question of "which stations are important", we need to specify it a bit more. Let's say we rephrase the question as "which routes are most popular". We therefore want to count the number times a bike goes from one station to the next.

# %%
for r, d in trips.iterrows():
    start = d['from_station_id']
    end = d['to_station_id']
    if (start, end) not in G.edges():
        G.add_edge(start, end, count=1)
    else:
        G.edge[start][end]['count'] += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-23357942f0cc> in <module>()
# ----> 1 for r, d in trips.iterrows():
#       2     print(r)
#
# /Users/ericmjl/anaconda/lib/python3.4/site-packages/pandas/core/frame.py in iterrows(self)
#     565         """
#     566         columns = self.columns
# --> 567         for k, v in zip(self.index, self.values):
#     568             s = Series(v, index=columns, name=k)
#     569             yield k, s
#
# /Users/ericmjl/anaconda/lib/python3.4/site-packages/pandas/core/generic.py in values(self)
#    2095         int32.
#    2096         """
# -> 2097         return self.as_matrix()
#    2098
#    2099     @property
#
# /Users/ericmjl/anaconda/lib/python3.4/site-packages/pandas/core/generic.py in as_matrix(self, columns)
#    2077         self._consolidate_inplace()
#    2078         if self._AXIS_REVERSED:
# -> 2079             return self._data.as_matrix(columns).T
#    2080         return self._data.as_matrix(columns)
#    2081
#
# /Users/ericmjl/anaconda/lib/python3.4/site-packages/pandas/core/internals.py in as_matrix(self, items)
#    2749             return mgr.blocks[0].get_values()
#    2750         else:
# -> 2751             return mgr._interleave()
#    2752
#    2753     def _interleave(self):
#
# /Users/ericmjl/anaconda/lib/python3.4/site-packages/pandas/core/internals.py in _interleave(self)
#    2776         for blk in self.blocks:
#    2777             rl = blk.mgr_locs
# -> 2778             result[rl.indexer] = blk.get_values(dtype)
#    2779             itemmask[rl.indexer] = 1
#    2780
#
# /Users/ericmjl/anaconda/lib/python3.4/site-packages/pandas/core/internals.py in get_values(self, dtype)
#    1932         if dtype == object:
#    1933             return lib.map_infer(self.values.ravel(), lib.Timestamp)\
# -> 1934                       .reshape(self.values.shape)
#    1935         return self.values
#    1936
#
# KeyboardInterrupt:
